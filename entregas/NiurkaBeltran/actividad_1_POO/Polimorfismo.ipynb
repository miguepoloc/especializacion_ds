# %% [markdown]
# POLIMORFISMO

# %%
class Rectangulo:
    def __init__(self, base, altura):
        self.base = base
        self.altura = altura

    def area(self):
        return self.base * self.altura


class Cuadrado:
    def __init__(self, lado):
        self.lado = lado

    def area(self):
        return self.lado * self.lado

# %%
rectangulo = Rectangulo(5, 3)
cuadrado = Cuadrado(4)

# %%
def mostrar_area(figura):
    print("Área:", figura.area())

# %%
mostrar_area(rectangulo)
mostrar_area(cuadrado)
# Out:
# Área: 15
# Área: 16

# %% [markdown]
# @startuml
# ' Ejemplo: Figuras (polimorfismo)
#
# class Rectangulo {
#     + base: int
#     + altura: int
#     + area()
# }
#
# class Cuadrado {
#     + lado: int
#     + area()
# }
#
# @enduml
