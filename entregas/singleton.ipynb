# %% [markdown]
# ## Actividad
# Implementa tu propio Singleton para una clase de configuración global.

# %%
import uuid
class Confing:
    def __init__(self):
        self.id = uuid.uuid4()

    def log(self, msg):
        print(f"Log:{msg} -ID: {self.id}")


class Globalconfing:
    _instance = None
    id = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
            cls._instance.id = uuid.uuid4()
        return cls._instance

    def log(self, msg):
        print(f"Singleton LOG:{msg}-ID:{self.id}")


logger1 = Globalconfing()
logger1.log('Primer log')


logger2 = Globalconfing()
logger2.log('Segundo log')

print(logger1 is logger2)
# Out:
# Singleton LOG:Primer log-ID:2aff5588-ce8c-4c3f-b679-ed9e8759f9b4
# Singleton LOG:Segundo log-ID:2aff5588-ce8c-4c3f-b679-ed9e8759f9b4
# True
