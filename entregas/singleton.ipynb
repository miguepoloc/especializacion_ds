# %%
class ConfiguracionApp:
    def __init__(self,tema,idioma):
        self.tema=tema
        self.idioma=idioma

Config1 = ConfiguracionApp('claro','es')
config2 = ConfiguracionApp('oscuro', 'en')

print(Config1.tema, Config1.idioma)
print(config2.tema,config2.idioma)
print(Config1 is config2)
# Out:
# claro es
# oscuro en
# False

# %%
class ConfiguracionApp:
    _instancia = None

    def __new__(cls,*args,**kwargs):
        if cls._instancia == None:
            cls._instancia = super().__new__(cls)
            cls._instancia.tema = 'claro'
            cls._instancia.idioma = 'es'
        return cls._instancia

    def Actualizar(self, tema=None, idioma=None):
        if tema:/
            self.tema=tema
        if idioma:
            self.idioma = idioma

config1 = ConfiguracionApp()
config2=ConfiguracionApp()
config2.Actualizar(tema = 'oscuro', idioma = 'en')

print(config1.tema, config1.idioma)
print(config2.tema, config2.idioma)
print(config1 is config2)
# Out:
# oscuro en
# oscuro en
# True
