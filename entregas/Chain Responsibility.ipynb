# %% [markdown]
# ## Actividad
# Crea una cadena de validadores para un formulario web donde cada validador revise un campo diferente.

# %%
class Web:
    def


class PrimerNivel(Web):
    def autentificar(self, solicitud):
# Out:
#   Cell In[3], line 2
#
#     ^
# _IncompleteInputError: incomplete input
