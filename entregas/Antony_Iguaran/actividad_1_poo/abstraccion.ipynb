# %% [markdown]
# # Solución a los ejercicios prácticos.
#
# Para este ejercicio, escogeré un objeto como a un automóvil y partire de dos contextos diferentes el cual se establecerán en dos clases.
#
# El primer contexto será al automóvil como un sistema de cobro, es decir, un peaje.
# Para esto estableceré los siguientes atributos:
#    -Placa
#    -Categoria del automóvil
#    -ID del tag del telepeaje.
# Los anteriores atributos se tendrán en cuenta para realizar validar el saldo y registrar el paso.

# %% [markdown]
# @startuml
# class Peaje {
#     + Placa: str
#     + Categoria del vehiculo: str
#     + iden: int
#     + validar_saldo()
# }
# @enduml

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Peaje:
    def __init__(self, placa: str, categoria_veh: str, iden:int) -> None:
        self.placa: str = placa
        self.categoria_veh: str = categoria_veh
        self.iden: int = iden

    def validar_saldo(self) -> None:
        print(f"Airplane is flying at {self.speed} km/h")

    def __str__(self) -> str:
        return f"PLACA: {self.placa}, CATEGORIA: {self.categoria_veh}, ID: {self.iden}"

sistem_peaje = Peaje("ABC123", "Automóvil", 1)
print(sistem_peaje)
sistem_peaje.validar_saldo()
